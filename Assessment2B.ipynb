# %% [markdown]
# ###### Assessment

# %% [markdown]
# ###### I am going to provide two .csv files , you are supposed to work on them and have to provide solutions to the following problems

# %% [markdown]
# ###### import necessary libraries

# %%
import pandas as pd

# %%
# skimmimg the individual csv file2 
pd.read_csv("G:/jupyter notebook/GUVI pandas/csv files/college_2.csv")
# Out:
#                       Name  python  python_en  mysql  computational_thinking  \
# 0            ASHOK KUMAR K     100          0     31                       9
# 1                  Chandru       0         20      0                       0
# 2        Ganesh Ramkumar R      -1         55     24                       6
# 3          Bodipudi Harini      -1          0     35                      -1
# 4                VIINU V P      -1        100     24                      -1
# 5               Poojitha Y       0         78     35                       0
# 6   Gowtham Chandrasekaran      -1          0      0                       3
# 7                Gowtham R      -1         60      4                       6
# 8                 shifak N      58          0      0                       0
# 9                  Balaji       -1        100     20                       0
# 10                Rushitha      -1         15     62                       9
# ...

# %%
# skimming the csv file2
pd.read_csv("G:/jupyter notebook/GUVI pandas/csv files/college_1.csv")
# Out:
#               Name  python  mysql  Previous Geekions  CodeKata Score  \
# 0        A.Dharani    82.0   20.0              24500           24500
# 1      V.JEEVITHA     82.0   20.0              21740           21740
# 2      HEMAVATHI.R   100.0  100.0              19680           19680
# 3      Mugunthan S   100.0   47.0              10610           10610
# 4      Sathammai.S   100.0    8.0               8980            8980
# ..             ...     ...    ...                ...             ...
# 79    KarthikeyanS    45.0    0.0                  0               0
# 80        BARATH.P    29.0    0.0                  0               0
# 81   N.Ajith kumar    82.0    0.0                  0               0
# 82    mohamed nabi     0.0    0.0                  0               0
# 83  yaser ahamed.A     0.0   27.0                  0               0
#
#                                 Department  Rising
# 0         Computer Science and Engineering       0
# ...

# %% [markdown]
# ###### merge those two csv files (after getting as dataframes, get them as a single dataframe)

# %%
df1=pd.read_csv("G:/jupyter notebook/GUVI pandas/csv files/college_1.csv")
df1.columns     
df2=pd.read_csv("G:/jupyter notebook/GUVI pandas/csv files/college_2.csv",usecols=df1.columns) #since nearly 70% of records has 
#                                                         no columns such as python en, computational so removing the columns
new_df=pd.concat([df1,df2],axis=0,ignore_index=True)
new_df
# Out:
#               Name  python  mysql  Previous Geekions  CodeKata Score  \
# 0        A.Dharani    82.0   20.0              24500           24500
# 1      V.JEEVITHA     82.0   20.0              21740           21740
# 2      HEMAVATHI.R   100.0  100.0              19680           19680
# 3      Mugunthan S   100.0   47.0              10610           10610
# 4      Sathammai.S   100.0    8.0               8980            8980
# ..             ...     ...    ...                ...             ...
# 114  praveen raj j    24.0    0.0               2380            2380
# 115     AMARNATH D    -1.0   12.0               1890            1890
# 116           bala    32.0    0.0               1720            1720
# 117           XY Z    -1.0   -1.0                  0               0
# 118      Hariharan    -1.0   -1.0                  0               0
#
#                                     Department  Rising
# 0             Computer Science and Engineering       0
# ...

# %% [markdown]
# ###### Take each csv file , split that csv file into multiple categories (example csv files are added in the repo)

# %% [markdown]
# ###### consider if the codekata score exceeds 15000 points(present week) then make a csv on those observations as Exceeded expectations.csv

# %% [markdown]
# ###### if  10000<codekata score<15000   (Reached_expectations.csv)

# %% [markdown]
# ###### if  7000<codekata score<10000   (Needs_Improvement.csv)

# %% [markdown]
# ###### if  codekate score < 7000        (Unsatisfactory.csv)

# %%
new_df[new_df["CodeKata Score"]>15000].to_csv("./Exceeded expectations.csv",index=False)
new_df[(new_df["CodeKata Score"]>10000) & (new_df["CodeKata Score"]<15000)].to_csv("./Reached_expectations.csv",index=False)
new_df[(new_df["CodeKata Score"]>7000) & (new_df["CodeKata Score"]<10000)].to_csv("./Needs_Improvement.csv",index=False)
new_df[new_df["CodeKata Score"]<7000].to_csv("./Unsatisfactory.csv",index=False)

# %% [markdown]
# ###### Average of previous week geekions vs this week geekions (i.e Previous Geekions vs CodeKata Score)

# %%
import matplotlib.pyplot as plt

# %%
new_df["Previous Geekions"].dtypes,new_df["CodeKata Score"].dtypes
# Out:
# (dtype('int64'), dtype('int64'))

# %%
new_df["Previous Geekions"].mean(),new_df["CodeKata Score"].mean()
# Out:
# (3842.3529411764707, 4051.764705882353)

# %%
x=["Previous Geekions","present Geekions"]
y=[new_df["Previous Geekions"].mean(),new_df["CodeKata Score"].mean()]
plt.bar(x,y,color=["r","g"])
plt.ylabel("codekata score")
plt.title("Performance of geeks over a week")
plt.show()

# %% [markdown]
# ###### No of students participated

# %%
print(f"The number of students participated are {len(new_df.Name.unique())}")
# Out:
# The number of students participated are 119

# %% [markdown]
# ###### #Average completion of python course or my_sql or python english or computational thinking

# %%
import numpy as np

# %%
avg=round(np.mean(new_df[["python","mysql"]].mean(axis=1)),2)
print(f"The average of completion of both python or mysql is {avg}")
# Out:
# The average of completion of both python or mysql is 38.93

# %% [markdown]
# ###### rising star of the week (top 3 candidate who performed well in that particular week)

# %%
new_df.nlargest(3,columns="Rising",keep="all")
# Out:
#                   Name  python  mysql  Previous Geekions  CodeKata Score  \
# 92            shifak N    58.0    0.0               5180            8320
# 86   Ganesh Ramkumar R    -1.0   24.0               8790           10790
# 102     Narasimhan Y L    -1.0    0.0               4800            6800
#
#                                  Department  Rising
# 92   Electronics and Electrical Engineering    3140
# 86         Computer Science and Engineering    2000
# 102        Computer Science and Engineering    2000

# %% [markdown]
# ###### Shining stars of the week (top 3 candidates who has highest geekions)

# %%
new_df.nlargest(3,columns="CodeKata Score",keep="all")
# Out:
#           Name  python  mysql  Previous Geekions  CodeKata Score  \
# 0    A.Dharani    82.0   20.0              24500           24500
# 1  V.JEEVITHA     82.0   20.0              21740           21740
# 2  HEMAVATHI.R   100.0  100.0              19680           19680
#
#                          Department  Rising
# 0  Computer Science and Engineering       0
# 1  Computer Science and Engineering       0
# 2  Computer Science and Engineering       0

# %% [markdown]
# ###### Department wise codekata performence (pie chart)

# %%
groups=new_df.groupby("Department")["CodeKata Score"].mean()
plt.pie(x=groups.values,labels=groups.index,autopct="%.2f")
plt.show()

# %% [markdown]
# ###### Department wise toppers (horizantal bar graph or any visual representations of your choice)

# %%
a=new_df.groupby("Department")[["Name","CodeKata Score"]].max()

# %%
a
# Out:
#                                                      Name  CodeKata Score
# Department
# Computer Science and Engineering              vijayakumar           24500
# Electronics and Communication Engineering       vignesh B           10040
# Electronics and Electrical Engineering     yaser ahamed.A           19400

# %%
arrays=np.hsplit(a.values,2)

# %%
plt.figure(figsize=(10,10))
fig, ax = plt.subplots()

bar_x = a.index
bar_height = arrays[1].reshape(-1,)
bar_tick_label = a.index
bar_label = arrays[0].reshape(-1,)

bar_plot = plt.bar(bar_x,bar_height,tick_label=bar_tick_label,color=["g","r","b"])

def autolabel(rects):
    for idx,rect in enumerate(bar_plot):
        height = rect.get_height()
        ax.text(rect.get_x() + rect.get_width()/2., 0.5*height,
                bar_label[idx],
                ha='center', va='bottom', rotation=90)

autolabel(bar_plot)
plt.xticks(rotation=45)
plt.show()
# https://moonbooks.org/Articles/How-to-add-text-on-a-bar-with-matplotlib-/
